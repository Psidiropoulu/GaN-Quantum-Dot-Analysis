# %% [markdown]
# Trying to get inspired by people's models, I looked at this one: https://github.com/arthijayaraman-lab/Automated-Atomic-Force-Microscopy-Image-Analysis

# %%
# !pip3 install porespy
# Out:
# Requirement already satisfied: porespy in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (3.0.2)
# Requirement already satisfied: dask in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (2026.7.1)
# Requirement already satisfied: deprecated in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (1.3.1)
# Requirement already satisfied: edt in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (3.1.2)
# Requirement already satisfied: imageio>=2.37.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (2.37.3)
# Requirement already satisfied: matplotlib in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (3.10.9)
# Requirement already satisfied: matplotlib-inline in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (0.2.2)
# Requirement already satisfied: nanomesh>=0.9.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (0.9.1)
# Requirement already satisfied: numba in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (0.66.0)
# Requirement already satisfied: numpy in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (2.2.6)
# Requirement already satisfied: numpy-stl>=3.2.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (4.0.0)
# Requirement already satisfied: pandas in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (2.3.3)
# Requirement already satisfied: psutil in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (7.2.2)
# Requirement already satisfied: pyevtk>=1.6.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (1.7.0)
# Requirement already satisfied: pywavelets>=1.8.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (1.8.0)
# Requirement already satisfied: rich in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (15.0.0)
# Requirement already satisfied: scikit-image in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (0.25.2)
# Requirement already satisfied: scipy in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (1.15.3)
# Requirement already satisfied: setuptools in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (83.0.0)
# Requirement already satisfied: tomli>=2.2.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (2.4.1)
# Requirement already satisfied: tqdm in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (4.70.0)
# Requirement already satisfied: trimesh>=4.5.3 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from porespy) (5.0.0)
# Requirement already satisfied: pillow>=8.3.2 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from imageio>=2.37.0->porespy) (12.3.0)
# Requirement already satisfied: traitlets in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib-inline->porespy) (5.15.1)
# Requirement already satisfied: IPython!=7.23 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (8.39.0)
# Requirement already satisfied: ipywidgets in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (8.1.8)
# Requirement already satisfied: itkwidgets in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (0.32.4)
# Requirement already satisfied: meshio>=5.3 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (5.3.5)
# Requirement already satisfied: pyvista in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (0.48.4)
# Requirement already satisfied: scikit-learn in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (1.7.2)
# Requirement already satisfied: triangle in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from nanomesh>=0.9.1->porespy) (20250106)
# Requirement already satisfied: decorator in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (5.3.1)
# Requirement already satisfied: exceptiongroup in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (2.20.0)
# Requirement already satisfied: stack_data in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from IPython!=7.23->nanomesh>=0.9.1->porespy) (4.16.0)
# Requirement already satisfied: wcwidth in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython!=7.23->nanomesh>=0.9.1->porespy) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from jedi>=0.16->IPython!=7.23->nanomesh>=0.9.1->porespy) (0.8.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from matplotlib->porespy) (2.9.0.post0)
# Requirement already satisfied: python-utils>=3.4.5 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from numpy-stl>=3.2.0->porespy) (4.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pexpect>4.3->IPython!=7.23->nanomesh>=0.9.1->porespy) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->porespy) (1.17.0)
# Requirement already satisfied: click>=8.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (8.4.2)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (2026.7.0)
# Requirement already satisfied: partd>=1.4.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (1.1.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from dask->porespy) (9.0.0)
# Requirement already satisfied: zipp>=3.20 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask->porespy) (4.1.0)
# Requirement already satisfied: locket in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from partd>=1.4.0->dask->porespy) (1.0.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from deprecated->porespy) (2.2.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from ipywidgets->nanomesh>=0.9.1->porespy) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from ipywidgets->nanomesh>=0.9.1->porespy) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from ipywidgets->nanomesh>=0.9.1->porespy) (3.0.16)
# Requirement already satisfied: colorcet in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (3.2.1)
# Requirement already satisfied: itk-core>=5.3.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (5.4.7)
# Requirement already satisfied: itk-filtering>=5.3.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (5.4.7)
# Requirement already satisfied: itk-numerics>=5.3.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (5.4.7)
# Requirement already satisfied: itk-meshtopolydata>=0.10 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (0.11.1)
# Requirement already satisfied: ipydatawidgets>=4.0.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (4.3.5)
# Requirement already satisfied: ipympl>=0.4.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (0.10.0)
# Requirement already satisfied: zstandard in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from itkwidgets->nanomesh>=0.9.1->porespy) (0.25.0)
# Requirement already satisfied: traittypes>=0.2.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from ipydatawidgets>=4.0.1->itkwidgets->nanomesh>=0.9.1->porespy) (0.2.3)
# Requirement already satisfied: llvmlite<0.49,>=0.48.0dev0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from numba->porespy) (0.48.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pandas->porespy) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pandas->porespy) (2026.3)
# Requirement already satisfied: cyclopts>=4.0.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pyvista->nanomesh>=0.9.1->porespy) (4.22.5)
# Requirement already satisfied: pooch in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pyvista->nanomesh>=0.9.1->porespy) (1.9.0)
# Requirement already satisfied: scooby>=0.5.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pyvista->nanomesh>=0.9.1->porespy) (0.11.2)
# Requirement already satisfied: vtk!=9.4.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pyvista->nanomesh>=0.9.1->porespy) (9.6.2)
# Requirement already satisfied: attrs>=23.1.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista->nanomesh>=0.9.1->porespy) (26.1.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista->nanomesh>=0.9.1->porespy) (0.18.0)
# Requirement already satisfied: rich-rst<3.0.0,>=1.3.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista->nanomesh>=0.9.1->porespy) (2.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from rich->porespy) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->porespy) (0.1.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pooch->pyvista->nanomesh>=0.9.1->porespy) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from pooch->pyvista->nanomesh>=0.9.1->porespy) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->nanomesh>=0.9.1->porespy) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->nanomesh>=0.9.1->porespy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->nanomesh>=0.9.1->porespy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from requests>=2.19.0->pooch->pyvista->nanomesh>=0.9.1->porespy) (2026.6.17)
# Requirement already satisfied: networkx>=3.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from scikit-image->porespy) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from scikit-image->porespy) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from scikit-image->porespy) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from scikit-learn->nanomesh>=0.9.1->porespy) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from scikit-learn->nanomesh>=0.9.1->porespy) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from stack_data->IPython!=7.23->nanomesh>=0.9.1->porespy) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from stack_data->IPython!=7.23->nanomesh>=0.9.1->porespy) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages (from stack_data->IPython!=7.23->nanomesh>=0.9.1->porespy) (0.2.3)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import cv2
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Model
import pywt
import porespy as ps
import scipy.ndimage as spim
from skimage.transform import radon
from sklearn.decomposition import PCA
from scipy.fftpack import dct
import time
from sklearn.mixture import GaussianMixture
from matplotlib.ticker import FormatStrFormatter
# Out:
# /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages/porespy/filters/_lt_methods.py:21: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   strel = {2: {'min': disk(1), 'max': square(3)}, 3: {'min': ball(1), 'max': cube(3)}}
# /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages/porespy/filters/_lt_methods.py:21: FutureWarning: `cube` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   strel = {2: {'min': disk(1), 'max': square(3)}, 3: {'min': ball(1), 'max': cube(3)}}
# /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages/porespy/metrics/_funcs.py:65: FutureWarning: `square` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   strel = {2: {"min": disk(1), "max": square(3)}, 3: {"min": ball(1), "max": cube(3)}}
# /Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/venv-ml/lib/python3.10/site-packages/porespy/metrics/_funcs.py:65: FutureWarning: `cube` is deprecated since version 0.25 and will be removed in version 0.27. Use `skimage.morphology.footprint_rectangle` instead.
#   strel = {2: {"min": disk(1), "max": square(3)}, 3: {"min": ball(1), "max": cube(3)}}

# %%
class Segment:
  def __init__(self, pca_comp = 3, pca_apply=False, win_ratio = 0.03, transform_string = "dft", stand_out_features = True, eql_hist = False, use_kmeans = True, use_gmm = False, no_clusters = 2, stats_to_use = "va", um_pix=5.21):
    self.pca_comp = pca_comp    # No. of Principal components to decompose 
    self.pca_apply = pca_apply  # flag to apply Principal component analysis on features
    self.win_ratio = win_ratio  # win factor (decides the size of the tile)
    self.transform_string = transform_string  # list of tranforms applied to extract features
    self.stand_out_features = stand_out_features  # flag to normalize features
    self.eql_hist = eql_hist  # flag to perform histogram equalization of input image 
    self.use_kmeans = use_kmeans  # flag to use kmeans for clustering 
    self.use_gmm = use_gmm  # flag to use gaussian mixture models for clustering 
    self.no_clusters = no_clusters  # No. of Clusters to form
    self.stats_to_use = stats_to_use  # list of satistics to use
    self.um_pix=um_pix   # length of one pix in nanometers
    self.model_stack = []  
    self.layer_names = ['conv1_relu', 'conv2_block3_2_relu', 'conv3_block1_2_relu']  # layers to use from ResNet50 for feature extraction
    self.transform_list = self.get_transform_list()

  def get_transform_list(self):
    transform_list = self.transform_string.split("_")
    return transform_list
      
  ############################################
  ############# Loop functions ###############
  ############################################

  def get_features(self, img1, transform):
    """
    function to extract features from tile.
    Input:
      img1(ndarray) : tile  
      transform(list (str)) : list of transform to perform to extract features  
    return:
      all_features(ndarray)  : feature vector
    """
    if "dlresnet50" in transform:
      self.load_ResNet50()
      all_features = self.get_ResNet50(img1)
    else:
      all_features = np.array([])
    if "radon" in transform :
      all_features=np.append(all_features,self.get_radon_features(img1), axis=0)
    if "dft" in transform :
      all_features=np.append(all_features,self.get_dft_features(img1), axis=0)
    if "dct" in transform :
      all_features=np.append(all_features,self.get_dct_features(img1), axis=0)
    if "dwt_biort" in transform :
      all_features=np.append(all_features,self.get_biort_features(img1), axis=0)
    if "dwt_haar" in transform :
      all_features=np.append(all_features,self.get_wavelget_haar_featureset_features(img1), axis=0)
    return all_features

  def slinding_window(self, img):
    """
    function to make tiles
    features:
      input(ndarray) : input image 
    return:
      all_trans_features(ndarray) : feature cube flattened
      i_ctr(int) : feature cube width
      j_ctr(int) : feature cube height
    """
    for transform in self.transform_list:
      img_features = []
      if "dlresnet50" in self.transform_list:
        win_siz = 32
        img_tiles = []
      else:
        win_siz = round((img.shape[0]*self.win_ratio + img.shape[1]*self.win_ratio)/2)

      i_ctr = 0
      for i in range(win_siz//2,img.shape[0]-(win_siz//2),1):
        j_ctr = 0
        for j in range(win_siz//2,img.shape[1]-(win_siz//2),1):
          if "dlresnet50" in transform:
            img_tiles.append(img[(i-(win_siz//2)):(i+(win_siz//2)), (j-(win_siz//2)):(j+(win_siz//2))])
          else:
            img_features.append(self.get_features(img[(i-(win_siz//2)):(i+(win_siz//2)), (j-(win_siz//2)):(j+(win_siz//2))],transform))
          j_ctr+=1
        i_ctr+=1
      if "dlresnet50" in transform:
        img_features = self.get_features(img_tiles, transform)
      img_features = np.array(img_features)
      if "all_trans_features" not in locals():
        all_trans_features = img_features.copy()
      else:
        all_trans_features = np.append(all_trans_features, img_features, axis=1)

    return all_trans_features, i_ctr, j_ctr

  ############################################
  ############## DL ResNet50 #################
  ############################################

  def load_ResNet50(self):
    """
    function to initalize ResNet50 model 
    Return:
      tf_model_object, tf_model_object, ...
    """
    model = tf.keras.applications.resnet50.ResNet50(
        include_top=False,
        weights='imagenet',
        input_tensor=None,
        input_shape=(32,32,3),
        pooling=None
    )

    for lyr in self.layer_names:
      self.model_stack.append(Model(inputs=model.input, outputs=model.get_layer(lyr).output))
    return self.model_stack

  def get_ResNet50(self, img):
    """
    function that returns features generated from ResNet50 model.  
    Input:
        img(ndarray) : tile 
    return:
        out_features(ndarray) : feature vector 

    """
    img = np.array(img)
    img = np.repeat(img[:, :, :, np.newaxis], 3, axis=3) # repeat gray scale image into 3 channels like rgb

    for img_t in np.split(img, 8, axis=0):  #maxPrimeFactors(img.shape[0])
      if len(self.model_stack)>0:
        output_1 = self.model_stack[0].predict(img_t)
        features = np.max(output_1,axis=(1, 2))
        features = np.append(features, np.mean(output_1,axis=(1, 2)), axis =1)
        features = np.append(features, np.var(output_1,axis=(1, 2)), axis =1)
      if len(self.model_stack)>1:
        output_2 = self.model_stack[1].predict(img_t)
        features = np.append(features, np.max(output_2,axis=(1, 2)), axis =1)
        features = np.append(features, np.mean(output_2,axis=(1, 2)), axis =1)
        features = np.append(features, np.var(output_2,axis=(1, 2)), axis =1)
      if len(self.model_stack)>2:
        output_3 = self.model_stack[2].predict(img_t)
        features = np.append(features, np.max(output_3,axis=(1, 2)), axis =1)
        features = np.append(features, np.mean(output_3,axis=(1, 2)), axis =1)
        features = np.append(features, np.var(output_3,axis=(1, 2)), axis =1)
      if 'out_features' not in locals():
        out_features = features.copy()
      else:
        out_features = np.append(out_features,features, axis = 0)
    
    return out_features



  ############################################
  ########### Domain Transforms ##############
  ############################################

  ####### Discrete Cosine transforms ########
  def get_dct_features(self, tile):
    """
    Discrete cosine transform (DCT) based feature extraction
    Input:
        tile(ndarray) : tile 
    return
        self.get_stats_feature_vector(dct_image) (ndarray) : feature vectore 
    """
    dct_image = dct(dct(tile.T, norm='ortho').T, norm='ortho')
    return self.get_stats_feature_vector(dct_image)

  ###### Discrete Fourirer transforms ########

  def get_dft_features(self, tile):
    """
    Discrete fourier transform (DFT) based feature extraction
    Input:
        tile(ndarray) : tile 
    return
        self.get_stats_feature_vector(dft_image) (ndarray) : feature vectore 
    """
    dft_image = np.fft.fft2(tile)
    dft_image = np.fft.fftshift(dft_image)
    return self.get_stats_feature_vector(dft_image)


  ########## Wavelet transforms ##############
  def get_biort_features(self, tile, level=2):
    """
    Discrete wavelet transform (DWT) bi-orthogonal wavelet based feature extraction
    Input:
        tile(ndarray) : tile 
        level(int) : level of decomposition
    return
        texture_features(ndarray) : feature vectore 
    """

    coeffs = pywt.swt2(tile, 'bior5.5', start_level=0, level = level)
    cD = coeffs[:][1]
    texture_features = []
    for detail_coeff_ind in range(len(cD)):
        for i in range(3):
            texture_features.append(self.get_stats_feature_vector(cD[detail_coeff_ind][1][i]))
    return texture_features

  def get_haar_features(self, tile, level = 4):
    """
    Discrete wavelet transform (DWT) Haar wavelet based feature extraction
    Input:
        tile(ndarray) : tile 
        level(int) : level of decomposition
    return
        texture_features(ndarray) : feature vectore 
    """
      
    coeffs = pywt.wavedec2(tile, "haar", level=level)
    cA, cD = coeffs[0], coeffs[1:]
    texture_features = []

    for detail_coeff in cD:
        texture_features.append(self.get_stats_feature_vector(detail_coeff))

    return texture_features

  ########### Radon transform  ###############
  def get_radon_features(self, tile):
    """
    Radon transform based feature extraction
    Input:
        tile(ndarray) : tile 
    return
        texture_features(ndarray) : feature vectore 
    """
    theta = np.linspace(0., 180., max(tile.shape), endpoint=False)
    sinogram = radon(tile, theta=theta, circle=False)
    texture_features = self.get_stats_feature_vector(sinogram)
    return texture_features


  ############################################
  ########## Clustering functions ############
  ############################################

  def fit_kmeans(self, feature_cube_flt, w, h):
    """
    predict clusters from feature cube using k-means

    Input:
        feature_cube_flt(ndarray) : feature cube flattened  
        w(int) : width of feature cube
        h(int) : height of feature cube
    return
        index_map(ndarray) : index map 
    """
      
    kmeans = KMeans(n_clusters=self.no_clusters)
    kmeans.fit(feature_cube_flt)
    ind_out = kmeans.predict(feature_cube_flt)
    out_img = np.zeros((w*h), dtype = float)
    for i in range(ind_out.shape[0]):
        out_img[i]=ind_out[i]
    index_map = out_img.reshape(w,h)
    return index_map

  def fit_gmm(self, feature_cube_flt, w, h):
    """
    predict clusters from feature cube using gmm
    Input:
        feature_cube_flt(ndarray) : feature cube flattened  
        w(int) : width of feature cube
        h(int) : height of feature cube
    return
        index_map(ndarray) : index map 
    """
    gmm = GaussianMixture(n_components=self.no_clusters)
    gmm.fit(dataset)
    ind_out = gmm.predict(dataset)
    out_img = np.zeros((w*h), dtype = float)
    for i in range(ind_out.shape[0]):
        out_img[i]=ind_out[i]
    index_map = out_img.reshape(w,h)
    return index_map


  ############################################
  ############# Aux functions ################
  ############################################

  ########## stats for feature extraction and dimension reduction ##########
  def get_stats_feature_vector(self, trans_out):
    """
    function to multiplex statistics to apply on domain transform outputs
    Input:
        trans_out(ndarray) : domain transform output
    Output:
        feature_vector(ndarray) : feature vector 
    """
    trans_out = np.abs(trans_out)
    trans_out = trans_out.flatten()
    feature_vector = []

    if "a" in self.stats_to_use:
      mean_trans_out = np.mean(trans_out)
      feature_vector.append(mean_trans_out)

    if "m" in self.stats_to_use:
      max_trans_out = np.max(trans_out)
      feature_vector.append(max_trans_out)

    if "v" in self.stats_to_use:
      variance_trans_out = np.var(trans_out)
      feature_vector.append(variance_trans_out)

    if "s" in self.stats_to_use:
      mean_trans_out = np.mean(trans_out)
      variance_trans_out = np.var(trans_out)
      skewness_trans_out = np.mean((trans_out - mean_trans_out) ** 3) / (variance_trans_out ** (3/2))
      feature_vector.append(skewness_trans_out)

    if "k" in self.stats_to_use:
      mean_trans_out = np.mean(trans_out)
      variance_trans_out = np.var(trans_out)
      kurtosis_trans_out = np.mean((trans_out - mean_trans_out) ** 4) / (variance_trans_out ** 2)
      feature_vector.append(kurtosis_trans_out)

    return feature_vector

  ########## PCA ##########
  def processing_apply_pca(self, feature_cube_flt):
    """
    function to apply Principal Component Analysis
    Input:
        feature_cube_flt(ndarray) : feature cube flattened 
    output:
        principalComponents(ndarray) : principal components
    """
    feature_cube_flt = self.processing_normalization(feature_cube_flt)
    pca = PCA(n_components=self.pca_comp)
    principalComponents = pca.fit_transform(feature_cube_flt)
    return principalComponents

  ########## normalising ##########
  def processing_normalization(self, feature_cube_flt):
    """
    Discription: function to normalize feature cube
    Input:
        feature_cube_flt(ndarray) : feature cube flattened 
    return:
        scaled_features(ndarray) : normalized feature cube flattened 
    """
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(feature_cube_flt)
    return scaled_features


  def get_diameter_distribution(self, img):
    """
    Function to calculate domain size distribution from index map
    uses porosity simulations on images 
    Input:
        img(ndarray) : index map
    Returns:
        fig(matplotlib object) : domain size distribution 
    #um_pi -> length of one pix in nanometers
    """
    thk = ps.filters.local_thickness(img)
    plt.rcParams.update({'font.size': 14})
    fig, ax = plt.subplots(1, 2, figsize=[10, 4], constrained_layout=True)

    ax[0].tick_params(left = False, right = False , labelleft = False ,
                    labelbottom = False, bottom = False)
    #thk = thk*(2*um_pix)  # gives diameter therefore its 2 * scale of pix to nanometers
    img0 = ax[0].imshow(thk*2*self.um_pix, cmap='viridis')

    fig.colorbar(img0, ax=ax[0], orientation='vertical')
    #thk = thk//(2*um_pix)
    psd = ps.metrics.pore_size_distribution(im=thk*2*self.um_pix,log=False,bins=11)
    #*2*um_pix  # gives diameter therefore its 2 * scale of pix to nanometers
    ax[1].plot(psd.bin_centers[:-1], -1*np.diff(psd.cdf), color="black")  # the results from the psd.pdf is very flaky. it gives different scales for different bin sizes and values check this out when free
    ax[1].tick_params('x', top=True)
    ax[1].tick_params('y', right=True)
    ax[1].set_ylim([0, 0.3])
    ax[1].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    return fig

# %%
# initalize segment class with segmenatation function variables 
segment = Segment(
    pca_comp = 3,
    pca_apply=False,
    win_ratio = 0.03,
    transform_string = "dft_dlresnet50", #"dl_resnet50",
    stand_out_features = True,
    eql_hist = False,
    use_kmeans = True,
    use_gmm = False,
    no_clusters = 2,
    stats_to_use = "vas",
    um_pix=5.21,
)

# %%
os.getcwd()
# Out:
# '/Users/polinabobrova/Desktop/GaN Quantum Dot Analysis/Ground-Truth'

# %%
# load microscopy images as rgb or gray scale images. 
inp_img = np.load("NPY-Ground-Truth/Scan3/channel_00___0_data.npy")

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

import data_preprocessing as dp

# %%
# view input microscopy images 
inp_img=dp.robust_polynomial_line_flatten(inp_img)
plt.imshow(inp_img)
plt.show()

# %%
# Generate feature cube from input microscopy image 
feature_cube_flat, w, h = segment.slinding_window(inp_img)
# Out:
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step

# %%
feature_cube_flat = np.array(feature_cube_flat)

# %%
# normalization on feature cube
feature_cube_flat_norm = segment.processing_normalization(feature_cube_flat)

# %%
# cluster feature cube based on similarity 
index_map = segment.fit_kmeans(feature_cube_flat_norm,w,h)

# %%
index_map = index_map*255

# %%
# view predicted index map
plt.imshow(index_map)
plt.show()

# %%
#Plot domain size distribution from index map
fig = segment.get_diameter_distribution(index_map)
